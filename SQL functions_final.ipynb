# %%
# Import library
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # EXTRACT & TRANSFORM

# %% [markdown]
# Bees Colony Census Data By County

# %%
# Store beeColonyCensusDataByCounty CSV into DataFrame
beeColonyCensusDataByCounty_file = "data/beeColonyCensusDataByCounty.csv"
beeColonyCensusDataByCounty_df = pd.read_csv(beeColonyCensusDataByCounty_file)
beeColonyCensusDataByCounty_df
# Out:
#       Year      Period    State  State ANSI Ag District  Ag District Code  \
# 0     2012  END OF DEC  ALABAMA           1  BLACK BELT                40
# 1     2012  END OF DEC  ALABAMA           1  BLACK BELT                40
# 2     2012  END OF DEC  ALABAMA           1  BLACK BELT                40
# 3     2012  END OF DEC  ALABAMA           1  BLACK BELT                40
# 4     2012  END OF DEC  ALABAMA           1  BLACK BELT                40
# ...    ...         ...      ...         ...         ...               ...
# 7825  2002  END OF DEC  WYOMING          56   SOUTHEAST                50
# 7826  2002  END OF DEC  WYOMING          56   SOUTHEAST                50
# 7827  2002  END OF DEC  WYOMING          56   SOUTHEAST                50
# 7828  2002  END OF DEC  WYOMING          56        WEST                30
# 7829  2002  END OF DEC  WYOMING          56        WEST                30
#
#        County  County ANSI Value CV (%)
# 0     AUTAUGA          1.0   119   27.7
# 1      DALLAS         47.0    65   27.7
# 2      ELMORE         51.0   190   27.7
# 3      GREENE         63.0    14   27.7
# 4        HALE         65.0    10   27.7
# ...       ...          ...   ...    ...
# 7825   GOSHEN         15.0   (D)    NaN
# 7826  LARAMIE         21.0   (D)    NaN
# 7827   PLATTE         31.0   (D)    NaN
# 7828  LINCOLN         23.0   (D)    NaN
# 7829    UINTA         41.0   (D)    NaN
#
# [7830 rows x 10 columns]

# %%
# Create new data for CensusDataByCounty_df w selected columns - Removing 'Period' since all rows have the same value
CensusDataByCounty_df = beeColonyCensusDataByCounty_df[[
    'Year', 'State', 'State ANSI', 'Ag District', 'Ag District Code', 'County', 'County ANSI', 'Value', 'CV (%)']].copy()
CensusDataByCounty_rename_df = CensusDataByCounty_df.rename(columns={'CV (%)':'CV_pct'})
CensusDataByCounty_rename_df
# Out:
#       Year    State  State ANSI Ag District  Ag District Code   County  \
# 0     2012  ALABAMA           1  BLACK BELT                40  AUTAUGA
# 1     2012  ALABAMA           1  BLACK BELT                40   DALLAS
# 2     2012  ALABAMA           1  BLACK BELT                40   ELMORE
# 3     2012  ALABAMA           1  BLACK BELT                40   GREENE
# 4     2012  ALABAMA           1  BLACK BELT                40     HALE
# ...    ...      ...         ...         ...               ...      ...
# 7825  2002  WYOMING          56   SOUTHEAST                50   GOSHEN
# 7826  2002  WYOMING          56   SOUTHEAST                50  LARAMIE
# 7827  2002  WYOMING          56   SOUTHEAST                50   PLATTE
# 7828  2002  WYOMING          56        WEST                30  LINCOLN
# 7829  2002  WYOMING          56        WEST                30    UINTA
#
#       County ANSI Value CV_pct
# 0             1.0   119   27.7
# 1            47.0    65   27.7
# 2            51.0   190   27.7
# 3            63.0    14   27.7
# 4            65.0    10   27.7
# ...           ...   ...    ...
# 7825         15.0   (D)    NaN
# 7826         21.0   (D)    NaN
# 7827         31.0   (D)    NaN
# 7828         23.0   (D)    NaN
# 7829         41.0   (D)    NaN
#
# [7830 rows x 9 columns]

# %%
# Drop rows with NaN values
CensusDataByCounty_rename_df = CensusDataByCounty_rename_df.dropna(how='any')

# Exclude data rows with '(D)' or '(H)' in Value & CV (%) columns
CensusDataByCounty_rename_df = CensusDataByCounty_rename_df.loc[(CensusDataByCounty_rename_df['Value'] != '(D)') & (CensusDataByCounty_rename_df['CV_pct'] != '(H)') & (CensusDataByCounty_rename_df['CV_pct'] != '(D)')]

# %%
# Convert columns with string of numbers to float/int
CensusDataByCounty_rename_df['Value'] = CensusDataByCounty_rename_df.Value.str.replace(',', '').astype(int)
CensusDataByCounty_rename_df['CV_pct'] = CensusDataByCounty_rename_df['CV_pct'].astype(float)

# CensusDataByCounty_df.dtypes
CensusDataByCounty_rename_df
# Out:
#       Year    State  State ANSI    Ag District  Ag District Code      County  \
# 0     2012  ALABAMA           1     BLACK BELT                40     AUTAUGA
# 1     2012  ALABAMA           1     BLACK BELT                40      DALLAS
# 2     2012  ALABAMA           1     BLACK BELT                40      ELMORE
# 3     2012  ALABAMA           1     BLACK BELT                40      GREENE
# 4     2012  ALABAMA           1     BLACK BELT                40        HALE
# ...    ...      ...         ...            ...               ...         ...
# 2752  2012  WYOMING          56  SOUTH CENTRAL                40     NATRONA
# 2753  2012  WYOMING          56  SOUTH CENTRAL                40  SWEETWATER
# 2754  2012  WYOMING          56      SOUTHEAST                50    CONVERSE
# 2756  2012  WYOMING          56      SOUTHEAST                50     LARAMIE
# 2760  2012  WYOMING          56           WEST                30       UINTA
#
#       County ANSI  Value  CV_pct
# 0             1.0    119    27.7
# 1            47.0     65    27.7
# 2            51.0    190    27.7
# 3            63.0     14    27.7
# 4            65.0     10    27.7
# ...           ...    ...     ...
# 2752         25.0   8253    55.5
# 2753         37.0    244    55.5
# 2754          9.0      8    55.5
# 2756         21.0    158    55.5
# 2760         41.0    136    55.5
#
# [1900 rows x 9 columns]

# %%
# Add an id column
CensusDataByCounty_rename_df.reset_index(drop=False, inplace=True)
CensusDataByCounty_rename_df = CensusDataByCounty_rename_df.rename(columns={'index':'id'})
CensusDataByCounty_rename_df.set_index('id', inplace=True)

CensusDataByCounty_rename_df.dtypes
# Out:
# Year                  int64
# State                object
# State ANSI            int64
# Ag District          object
# Ag District Code      int64
# County               object
# County ANSI         float64
# Value                 int32
# CV_pct              float64
# dtype: object

# %% [markdown]
# Bees Colony Loss Data

# %%
# Store beeColonyLoss xlsx into DataFrame
beeColonyLoss_file = "data/beeColonyLossCSV.csv"
beeColonyLoss_df = pd.read_csv(beeColonyLoss_file)
beeColonyLoss_df
# Out:
#         Year  Season                 State Total Annual Loss  Beekeepers  \
# 0    2016/17  Annual         Massachusetts            15.90%          87
# 1    2016/17  Annual               Montana            17.10%          21
# 2    2016/17  Annual                Nevada            23.00%          13
# 3    2016/17  Annual                 Maine            23.30%          65
# 4    2016/17  Annual               Wyoming            23.40%          18
# ..       ...     ...                   ...               ...         ...
# 360  2010/11  Annual           Puerto Rico               NaN           1
# 361  2010/11  Annual                Alaska               NaN           2
# 362  2010/11  Annual  District of Columbia               NaN           1
# 363  2010/11  Annual               Wyoming               NaN           2
# 364  2010/11  Annual                Nevada               NaN           3
#
#     Beekeepers Exclusive to State  Colonies Colonies Exclusive to State
# 0                          94.30%     27186                       2.30%
# 1                          52.40%     35905                       0.30%
# 2                          92.30%      2512                       5.20%
# 3                          93.80%     41102                       1.40%
# 4                          77.80%      6521                       1.40%
# ..                            ...       ...                         ...
# 360                       100.00%        12                     100.00%
# 361                        50.00%         6                     100.00%
# 362                       100.00%         4                     100.00%
# 363                       100.00%      3883                     100.00%
# 364                        33.30%      3581                       0.30%
#
# [365 rows x 8 columns]

# %%
# Create new data for ColonyLoss_df w selected columns - Removing 'Season' since all rows have the same value
ColonyLoss_df = beeColonyLoss_df[['Year', 'State', 'Total Annual Loss', 'Beekeepers',
       'Beekeepers Exclusive to State', 'Colonies',
       'Colonies Exclusive to State']].copy()

ColonyLoss_renamed_df = ColonyLoss_df.rename(columns={
    'Total Annual Loss':'Total Annual Loss_pct',
    'Beekeepers Exclusive to State': 'Beekeepers Exclusive to State_pct',
    'Colonies Exclusive to State': 'Colonies Exclusive to State_pct'
})

# %%
# Drop rows with NaN values
ColonyLoss_renamed_df = ColonyLoss_renamed_df.dropna(how='any')
ColonyLoss_renamed_df
# Out:
#         Year          State Total Annual Loss_pct  Beekeepers  \
# 0    2016/17  Massachusetts                15.90%          87
# 1    2016/17        Montana                17.10%          21
# 2    2016/17         Nevada                23.00%          13
# 3    2016/17          Maine                23.30%          65
# 4    2016/17        Wyoming                23.40%          18
# ..       ...            ...                   ...         ...
# 355  2010/11  West Virginia                78.60%          25
# 356  2010/11           Iowa                80.70%          14
# 357  2010/11       Michigan                83.50%          99
# 358  2010/11        Georgia                84.70%          61
# 359  2010/11          Maine                86.90%          43
#
#     Beekeepers Exclusive to State_pct  Colonies  \
# 0                              94.30%     27186
# 1                              52.40%     35905
# 2                              92.30%      2512
# 3                              93.80%     41102
# 4                              77.80%      6521
# ..                                ...       ...
# 355                            92.00%       509
# 356                            85.70%      1037
# 357                            97.00%     10320
# 358                            96.70%      5923
# 359                            93.00%      5668
#
#     Colonies Exclusive to State_pct
# 0                             2.30%
# 1                             0.30%
# 2                             5.20%
# 3                             1.40%
# 4                             1.40%
# ..                              ...
# 355                          48.70%
# 356                          68.80%
# 357                          21.90%
# 358                          20.80%
# 359                          13.80%
#
# [349 rows x 7 columns]

# %%
# Convert columns with string of numbers to float
ColonyLoss_renamed_df['Total Annual Loss_pct'] = ColonyLoss_renamed_df['Total Annual Loss_pct'].str.replace('%', '').astype(float)
ColonyLoss_renamed_df['Beekeepers Exclusive to State_pct'] = ColonyLoss_renamed_df['Beekeepers Exclusive to State_pct'].str.replace('%', '').astype(float)
ColonyLoss_renamed_df['Colonies Exclusive to State_pct'] = ColonyLoss_renamed_df['Colonies Exclusive to State_pct'].str.replace('%', '').astype(float)

# ColonyLoss_renamed_df.dtypes
ColonyLoss_renamed_df
# Out:
#         Year          State  Total Annual Loss_pct  Beekeepers  \
# 0    2016/17  Massachusetts                   15.9          87
# 1    2016/17        Montana                   17.1          21
# 2    2016/17         Nevada                   23.0          13
# 3    2016/17          Maine                   23.3          65
# 4    2016/17        Wyoming                   23.4          18
# ..       ...            ...                    ...         ...
# 355  2010/11  West Virginia                   78.6          25
# 356  2010/11           Iowa                   80.7          14
# 357  2010/11       Michigan                   83.5          99
# 358  2010/11        Georgia                   84.7          61
# 359  2010/11          Maine                   86.9          43
#
#      Beekeepers Exclusive to State_pct  Colonies  \
# 0                                 94.3     27186
# 1                                 52.4     35905
# 2                                 92.3      2512
# 3                                 93.8     41102
# 4                                 77.8      6521
# ..                                 ...       ...
# 355                               92.0       509
# 356                               85.7      1037
# 357                               97.0     10320
# 358                               96.7      5923
# 359                               93.0      5668
#
#      Colonies Exclusive to State_pct
# 0                                2.3
# 1                                0.3
# 2                                5.2
# 3                                1.4
# 4                                1.4
# ..                               ...
# 355                             48.7
# 356                             68.8
# 357                             21.9
# 358                             20.8
# 359                             13.8
#
# [349 rows x 7 columns]

# %%
# Cleaning up the year column to show a single year
ColonyLoss_renamed_df['Year'] = ColonyLoss_renamed_df['Year'].str.slice(0, 4)
ColonyLoss_renamed_df['Year'] = ColonyLoss_renamed_df['Year'].astype(int)
ColonyLoss_renamed_df
# Out:
#      Year          State  Total Annual Loss_pct  Beekeepers  \
# 0    2016  Massachusetts                   15.9          87
# 1    2016        Montana                   17.1          21
# 2    2016         Nevada                   23.0          13
# 3    2016          Maine                   23.3          65
# 4    2016        Wyoming                   23.4          18
# ..    ...            ...                    ...         ...
# 355  2010  West Virginia                   78.6          25
# 356  2010           Iowa                   80.7          14
# 357  2010       Michigan                   83.5          99
# 358  2010        Georgia                   84.7          61
# 359  2010          Maine                   86.9          43
#
#      Beekeepers Exclusive to State_pct  Colonies  \
# 0                                 94.3     27186
# 1                                 52.4     35905
# 2                                 92.3      2512
# 3                                 93.8     41102
# 4                                 77.8      6521
# ..                                 ...       ...
# 355                               92.0       509
# 356                               85.7      1037
# 357                               97.0     10320
# 358                               96.7      5923
# 359                               93.0      5668
#
#      Colonies Exclusive to State_pct
# 0                                2.3
# 1                                0.3
# 2                                5.2
# 3                                1.4
# 4                                1.4
# ..                               ...
# 355                             48.7
# 356                             68.8
# 357                             21.9
# 358                             20.8
# 359                             13.8
#
# [349 rows x 7 columns]

# %%
# Add an id column
ColonyLoss_renamed_df.reset_index(drop=False, inplace=True)
ColonyLoss_renamed_df = ColonyLoss_renamed_df.rename(columns={'index':'id'})
ColonyLoss_renamed_df.set_index('id', inplace=True)

ColonyLoss_renamed_df.dtypes
# Out:
# Year                                   int32
# State                                 object
# Total Annual Loss_pct                float64
# Beekeepers                             int64
# Beekeepers Exclusive to State_pct    float64
# Colonies                               int64
# Colonies Exclusive to State_pct      float64
# dtype: object

# %% [markdown]
# Bee Colony Survey Data By State

# %%
# Store beeColonySurveyDataByState csv into DataFrame
beeColonySurveyDataByState = "data/beeColonySurveyDataByState.csv"
beeColonySurveyDataByState_df = pd.read_csv(beeColonySurveyDataByState)
beeColonySurveyDataByState_df
# Out:
#       Year          Period  Week Ending          State  State ANSI  Watershed  \
# 0     2017    JAN THRU MAR          NaN        ALABAMA           1        NaN
# 1     2017    JAN THRU MAR          NaN        ARIZONA           4        NaN
# 2     2017    JAN THRU MAR          NaN       ARKANSAS           5        NaN
# 3     2017    JAN THRU MAR          NaN     CALIFORNIA           6        NaN
# 4     2017    JAN THRU MAR          NaN       COLORADO           8        NaN
# ...    ...             ...          ...            ...         ...        ...
# 3391  1987  MARKETING YEAR          NaN       VIRGINIA          51        NaN
# 3392  1987  MARKETING YEAR          NaN     WASHINGTON          53        NaN
# 3393  1987  MARKETING YEAR          NaN  WEST VIRGINIA          54        NaN
# 3394  1987  MARKETING YEAR          NaN      WISCONSIN          55        NaN
# 3395  1987  MARKETING YEAR          NaN        WYOMING          56        NaN
#
#              Data Item    Value  CV (%)
# 0     ADDED & REPLACED      570     NaN
# 1     ADDED & REPLACED    2,900     NaN
# 2     ADDED & REPLACED      430     NaN
# 3     ADDED & REPLACED  215,000     NaN
# 4     ADDED & REPLACED      100     NaN
# ...                ...      ...     ...
# 3391         INVENTORY   25,000     NaN
# 3392         INVENTORY   75,000     NaN
# 3393         INVENTORY   21,000     NaN
# 3394         INVENTORY   92,000     NaN
# 3395         INVENTORY   39,000     NaN
#
# [3396 rows x 9 columns]

# %%
# Create new data for SurveyDataByState_df w selected columns - removing 'Week Ending', 'Watershed', 'CV (%)' b/c none of the rows have data
SurveyDataByState_df = beeColonySurveyDataByState_df[[
    'Year', 'Period', 'State', 'State ANSI', 'Data Item', 'Value']].copy()

# Note: There's no NaN values
SurveyDataByState_df = SurveyDataByState_df.dropna(how='any') 
SurveyDataByState_df
# Out:
#       Year          Period          State  State ANSI         Data Item  \
# 0     2017    JAN THRU MAR        ALABAMA           1  ADDED & REPLACED
# 1     2017    JAN THRU MAR        ARIZONA           4  ADDED & REPLACED
# 2     2017    JAN THRU MAR       ARKANSAS           5  ADDED & REPLACED
# 3     2017    JAN THRU MAR     CALIFORNIA           6  ADDED & REPLACED
# 4     2017    JAN THRU MAR       COLORADO           8  ADDED & REPLACED
# ...    ...             ...            ...         ...               ...
# 3391  1987  MARKETING YEAR       VIRGINIA          51         INVENTORY
# 3392  1987  MARKETING YEAR     WASHINGTON          53         INVENTORY
# 3393  1987  MARKETING YEAR  WEST VIRGINIA          54         INVENTORY
# 3394  1987  MARKETING YEAR      WISCONSIN          55         INVENTORY
# 3395  1987  MARKETING YEAR        WYOMING          56         INVENTORY
#
#         Value
# 0         570
# 1       2,900
# 2         430
# 3     215,000
# 4         100
# ...       ...
# 3391   25,000
# 3392   75,000
# 3393   21,000
# 3394   92,000
# 3395   39,000
#
# [3396 rows x 6 columns]

# %%
# Convert columns with string of numbers to float
SurveyDataByState_df['Value'] = SurveyDataByState_df.Value.str.replace(',', '').astype(int)

SurveyDataByState_df
# Out:
#       Year          Period          State  State ANSI         Data Item  \
# 0     2017    JAN THRU MAR        ALABAMA           1  ADDED & REPLACED
# 1     2017    JAN THRU MAR        ARIZONA           4  ADDED & REPLACED
# 2     2017    JAN THRU MAR       ARKANSAS           5  ADDED & REPLACED
# 3     2017    JAN THRU MAR     CALIFORNIA           6  ADDED & REPLACED
# 4     2017    JAN THRU MAR       COLORADO           8  ADDED & REPLACED
# ...    ...             ...            ...         ...               ...
# 3391  1987  MARKETING YEAR       VIRGINIA          51         INVENTORY
# 3392  1987  MARKETING YEAR     WASHINGTON          53         INVENTORY
# 3393  1987  MARKETING YEAR  WEST VIRGINIA          54         INVENTORY
# 3394  1987  MARKETING YEAR      WISCONSIN          55         INVENTORY
# 3395  1987  MARKETING YEAR        WYOMING          56         INVENTORY
#
#        Value
# 0        570
# 1       2900
# 2        430
# 3     215000
# 4        100
# ...      ...
# 3391   25000
# 3392   75000
# 3393   21000
# 3394   92000
# 3395   39000
#
# [3396 rows x 6 columns]

# %%
# Add an id column
SurveyDataByState_df.reset_index(drop=False, inplace=True)
SurveyDataByState_df = SurveyDataByState_df.rename(columns={'index':'id'})
SurveyDataByState_df.set_index('id', inplace=True)

SurveyDataByState_df.dtypes
# Out:
# Year           int64
# Period        object
# State         object
# State ANSI     int64
# Data Item     object
# Value          int32
# dtype: object

# %% [markdown]
# # LOAD

# %%
# Create database connection
engine = create_engine("sqlite:///data/bee_colony.sqlite")
conn = engine.connect()

# %%
# Confirm tables
engine.table_names()
# Out:
# ['census_county', 'census_state', 'colonyloss']

# %%
# Load SurveyDataByState_df into database
SurveyDataByState_df.to_sql(name='census_state', con=engine, if_exists='append', index=True)

# %%
# Load CensusDataByCounty_df into database
CensusDataByCounty_rename_df.to_sql(name='census_county', con=engine, if_exists='append', index=True)

# %%
# Load ColonyLoss_renamed_df into database
ColonyLoss_renamed_df.to_sql(name='colonyloss', con=engine, if_exists='append', index=True)

# %%
# Verify we can query from the database
pd.read_sql_query('select * from census_state', con=engine).head()
# Out:
#    id  Year        Period       State  State ANSI         Data Item   Value
# 0   0  2017  JAN THRU MAR     ALABAMA           1  ADDED & REPLACED     570
# 1   1  2017  JAN THRU MAR     ARIZONA           4  ADDED & REPLACED    2900
# 2   2  2017  JAN THRU MAR    ARKANSAS           5  ADDED & REPLACED     430
# 3   3  2017  JAN THRU MAR  CALIFORNIA           6  ADDED & REPLACED  215000
# 4   4  2017  JAN THRU MAR    COLORADO           8  ADDED & REPLACED     100

# %%
pd.read_sql_query('select * from census_county', con=engine).head()
# Out:
#    id  Year    State  State ANSI Ag District  Ag District Code   County  \
# 0   0  2012  ALABAMA           1  BLACK BELT                40  AUTAUGA
# 1   1  2012  ALABAMA           1  BLACK BELT                40   DALLAS
# 2   2  2012  ALABAMA           1  BLACK BELT                40   ELMORE
# 3   3  2012  ALABAMA           1  BLACK BELT                40   GREENE
# 4   4  2012  ALABAMA           1  BLACK BELT                40     HALE
#
#    County ANSI  Value  CV_pct
# 0          1.0    119    27.7
# 1         47.0     65    27.7
# 2         51.0    190    27.7
# 3         63.0     14    27.7
# 4         65.0     10    27.7

# %%
pd.read_sql_query('select * from colonyloss', con=engine).head()
# Out:
#    id  Year          State  Total Annual Loss_pct  Beekeepers  \
# 0   0  2016  Massachusetts                   15.9          87
# 1   1  2016        Montana                   17.1          21
# 2   2  2016         Nevada                   23.0          13
# 3   3  2016          Maine                   23.3          65
# 4   4  2016        Wyoming                   23.4          18
#
#    Beekeepers Exclusive to State_pct  Colonies  \
# 0                               94.3     27186
# 1                               52.4     35905
# 2                               92.3      2512
# 3                               93.8     41102
# 4                               77.8      6521
#
#    Colonies Exclusive to State_pct
# 0                              2.3
# 1                              0.3
# 2                              5.2
# 3                              1.4
# 4                              1.4
